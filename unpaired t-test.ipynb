# %%
from scipy.stats import ttest_ind_from_stats

# %%
mean_co_2x_pop = 16; std_co_2x_pop =  4.8
mean_co_2x_gen = 33.04; std_co_2x_gen =  2.72
mean_co_2x_fit = 303.04; std_co_2x_fit =  79.547
mean_co_2x_time = 0.038; std_co_2x_time = 0.012

mean_co_ux_pop = 13; std_co_ux_pop =  4.8
mean_co_ux_gen = 27.28; std_co_ux_gen =  2.691
mean_co_ux_fit = 211.48; std_co_ux_fit =  63.377
mean_co_ux_time = 0.407; std_co_ux_time = 0.142

# %%
mean_dec_2x_pop = 49; std_dec_2x_pop =  21.257
mean_dec_2x_gen = 53.76; std_dec_2x_gen =  13.064
mean_dec_2x_fit = 1348.76; std_dec_2x_fit =  565.453
mean_dec_2x_time = 2.012; std_dec_2x_time = 1.070

mean_dec_ux_pop = 49; std_dec_ux_pop =  29.518
mean_dec_ux_gen = 45.8; std_dec_ux_gen =  7.818
mean_dec_ux_fit = 1156.2; std_dec_ux_fit =  658.954
mean_dec_ux_time = 4.196 ; std_dec_ux_time = 2.512

# %%
mean_nondec_2x_pop = 20; std_nondec_2x_pop =  5.986
mean_nondec_2x_gen = 54.88; std_nondec_2x_gen = 7.235
mean_nondec_2x_fit = 614.68; std_nondec_2x_fit =  168.337
mean_nondec_2x_time = 0.798 ; std_nondec_2x_time = 0.233

mean_nondec_ux_pop = 18; std_nondec_ux_pop =  4.308
mean_nondec_ux_gen = 43.84; std_nondec_ux_gen = 6.156
mean_nondec_ux_fit = 450.44; std_nondec_ux_fit =  92.659
mean_nondec_ux_time = 1.508 ; std_nondec_ux_time = 0.344

# %%
mean_dec_nolink_2x_pop = 50; std_dec_nolink_2x_pop =  30.973
mean_dec_nolink_2x_gen = 53.44; std_dec_nolink_2x_gen = 8.153
mean_dec_nolink_2x_fit = 1391.84; std_dec_nolink_2x_fit =  758.572
mean_dec_nolink_2x_time = 3.622 ; std_dec_nolink_2x_time = 2.240

mean_dec_nolink_ux_pop = 37; std_dec_nolink_ux_pop =  23.200
mean_dec_nolink_ux_gen = 46.08; std_dec_nolink_ux_gen = 7.381
mean_dec_nolink_ux_fit = 944.68; std_dec_nolink_ux_fit =  635.402
mean_dec_nolink_ux_time = 4.160 ; std_dec_nolink_ux_time = 2.980

# %%
mean_nondec_nolink_2x_pop = 22; std_nondec_nolink_2x_pop =  4.270
mean_nondec_nolink_2x_gen = 50.16; std_nondec_nolink_2x_gen = 8.326
mean_nondec_nolink_2x_fit = 601.56; std_nondec_nolink_2x_fit =  86.088
mean_nondec_nolink_2x_time = 1.418 ; std_nondec_nolink_2x_time = 0.226

mean_nondec_nolink_ux_pop = 18; std_nondec_nolink_ux_pop =  4.0
mean_nondec_nolink_ux_gen = 42.88; std_nondec_nolink_ux_gen = 6.179
mean_nondec_nolink_ux_fit = 431.88; std_nondec_nolink_ux_fit =  114.514
mean_nondec_nolink_ux_time = 1.915 ; std_nondec_nolink_ux_time = 0.542

# %%
pop = np.array([]).reshape(0,2)

#pop = np.vstack((pop,[mean_co_2x_pop,std_co_2x_pop]))
#pop = np.vstack((pop,[mean_co_ux_pop,std_co_ux_pop]))

#pop = np.vstack((pop,[mean_dec_2x_pop,std_dec_2x_pop]))
#pop = np.vstack((pop,[mean_dec_ux_pop,std_dec_ux_pop]))

#pop = np.vstack((pop,[mean_nondec_2x_pop,std_nondec_2x_pop]))
#pop = np.vstack((pop,[mean_nondec_ux_pop,std_nondec_ux_pop]))

#pop = np.vstack((pop,[mean_dec_nolink_2x_pop,std_dec_nolink_2x_pop]))
pop = np.vstack((pop,[mean_dec_nolink_ux_pop,std_dec_nolink_ux_pop]))

#pop = np.vstack((pop,[mean_nondec_nolink_2x_pop,std_nondec_nolink_2x_pop]))
pop = np.vstack((pop,[mean_nondec_nolink_ux_pop,std_nondec_nolink_ux_pop]))

for i in range(len(pop)):
    for j in range(len(pop)):
        comapre = pop[i]==pop[j]
        if comapre.all() == False:
            mean1 = pop[i][0]
            mean2 = pop[j][0]
            std1 = pop[i][1]
            std2 = pop[j][1]
            n1 = 25
            n2 = 25
            alpha = 0.05
            tstat, pvalue = ttest_ind_from_stats(mean1, std1, n1, mean2, std2, n2)
            if pvalue <= alpha:
                print(indx[i],indx[j])
                print(f'Reject the null hypothesis that the means are equal. {tstat, pvalue}')

# %%
indx = np.array([]).reshape(0,1)

# indx = np.vstack((indx,['co_2x']))
# indx = np.vstack((indx,['co_ux']))

#indx = np.vstack((indx,['dec_2x']))
#indx = np.vstack((indx,['dec_ux']))

#indx = np.vstack((indx,['nondec_2x']))
#indx = np.vstack((indx,['nondec_ux']))

indx = np.vstack((indx,['dec_nolink_2x']))
#indx = np.vstack((indx,['dec_nolink_ux']))

indx = np.vstack((indx,['nondec_nolink_2x']))
#indx = np.vstack((indx,['nondec_nolink_ux']))

# %%
gen = np.array([]).reshape(0,2)

#gen = np.vstack((gen,[mean_co_2x_gen,std_co_2x_gen]))
#gen = np.vstack((gen,[mean_co_ux_gen,std_co_ux_gen]))

#gen = np.vstack((gen,[mean_dec_2x_gen,std_dec_2x_gen]))
#gen = np.vstack((gen,[mean_dec_ux_gen,std_dec_ux_gen]))

#gen = np.vstack((gen,[mean_nondec_2x_gen,std_nondec_2x_gen]))
#gen = np.vstack((gen,[mean_nondec_ux_gen,std_nondec_ux_gen]))

gen = np.vstack((gen,[mean_dec_nolink_2x_gen,std_dec_nolink_2x_gen]))
#gen = np.vstack((gen,[mean_dec_nolink_ux_gen,std_dec_nolink_ux_gen]))

gen = np.vstack((gen,[mean_nondec_nolink_2x_gen,std_nondec_nolink_2x_gen]))
#gen = np.vstack((gen,[mean_nondec_nolink_ux_gen,std_nondec_nolink_ux_gen]))

for i in range(len(gen)):
    for j in range(len(gen)):
        comapre = gen[i]==gen[j]
        if comapre.all() == False:
            mean1 = gen[i][0]
            mean2 = gen[j][0]
            std1 = gen[i][1]
            std2 = gen[j][1]
            n1 = 25
            n2 = 25
            alpha = 0.05
            tstat, pvalue = ttest_ind_from_stats(mean1, std1, n1, mean2, std2, n2)
            if pvalue <= alpha:
                print(indx[i],indx[j])
                print(f'Reject the null hypothesis that the means are equal. {tstat, pvalue}')

# %%
fit = np.array([]).reshape(0,2)

fit = np.vstack((fit,[mean_co_2x_fit,std_co_2x_fit]))
# fit = np.vstack((fit,[mean_co_ux_fit,std_co_ux_fit]))

#fit = np.vstack((fit,[mean_dec_2x_fit,std_dec_2x_fit]))
#fit = np.vstack((fit,[mean_dec_ux_fit,std_dec_ux_fit]))

fit = np.vstack((fit,[mean_nondec_2x_fit,std_nondec_2x_fit]))
#fit = np.vstack((fit,[mean_nondec_ux_fit,std_nondec_ux_fit]))

#fit = np.vstack((fit,[mean_dec_nolink_2x_fit,std_dec_nolink_2x_fit]))
#fit = np.vstack((fit,[mean_dec_nolink_ux_fit,std_dec_nolink_ux_fit]))

#fit = np.vstack((fit,[mean_nondec_nolink_2x_fit,std_nondec_nolink_2x_fit]))
#fit = np.vstack((fit,[mean_nondec_nolink_ux_fit,std_nondec_nolink_ux_fit]))

for i in range(len(fit)):
    for j in range(len(fit)):
        comapre = fit[i]==fit[j]
        if comapre.all() == False:
            mean1 = fit[i][0]
            mean2 = fit[j][0]
            std1 = fit[i][1]
            std2 = fit[j][1]
            n1 = 25
            n2 = 25
            alpha = 0.05
            tstat, pvalue = ttest_ind_from_stats(mean1, std1, n1, mean2, std2, n2)
            if pvalue <= alpha:
                print(indx[i],indx[j])
                print(f'Reject the null hypothesis that the means are equal. {tstat, pvalue}')

# %%
time = np.array([]).reshape(0,2)

# time = np.vstack((time,[mean_co_2x_time,std_co_2x_time]))
# time = np.vstack((time,[mean_co_ux_time,std_co_ux_time]))

#time = np.vstack((time,[mean_dec_2x_time,std_dec_2x_time]))
#time = np.vstack((time,[mean_dec_ux_time,std_dec_ux_time]))

#time = np.vstack((time,[mean_nondec_2x_time,std_nondec_2x_time]))
time = np.vstack((time,[mean_nondec_ux_time,std_nondec_ux_time]))

#time = np.vstack((time,[mean_dec_nolink_2x_time,std_dec_nolink_2x_time]))
#time = np.vstack((time,[mean_dec_nolink_ux_time,std_dec_nolink_ux_time]))

#time = np.vstack((time,[mean_nondec_nolink_2x_time,std_nondec_nolink_2x_time]))
time = np.vstack((time,[mean_nondec_nolink_ux_time,std_nondec_nolink_ux_time]))

for i in range(len(time)):
    for j in range(len(time)):
        comapre = time[i]==time[j]
        if comapre.all() == False:
            mean1 = time[i][0]
            mean2 = time[j][0]
            std1 = time[i][1]
            std2 = time[j][1]
            n1 = 25
            n2 = 25
            alpha = 0.05
            tstat, pvalue = ttest_ind_from_stats(mean1, std1, n1, mean2, std2, n2)
            if pvalue <= alpha:
                print(indx[i],indx[j])
                print(f'Reject the null hypothesis that the means are equal. {tstat, pvalue}')

# %%
# optimal population sizes

# 1. co_2x and co_ux (2.209708691207961, 0.03192870565025369)
# 2. nondec_nolink_2x and nondec_nolink_ux  (3.4182840608696483, 0.0012936459169105394)

# 3. dec_2x and nondec_2x (6.565912296099305, 3.407315770784634e-08)
# 4. dec_ux and nondec_ux (5.195987832423207, 4.122547311520044e-06)

# 5. co_ux and nondec_ux (-3.876138380471197, 0.000321792366792468)
# 6. co_2x and nondec_2x (-2.6066029220048894, 0.012145930182714839)

# 7. dec_nolink_2x and nondec_nolink_2x (4.477714575403011, 4.65072465737413e-05)
# 8. dec_nolink_ux and nondec_nolink_ux (4.035289267056598, 0.00019494330327989338)

# %%
# number of generations

# 1. co_2x and co_ux (7.527031169725987, 1.1499132376454823e-09)
# 2. dec_2x and dec_ux (2.6141858227432575, 0.011913090784530275)
# 3. nondec_2x and nondec_ux (5.810797997067497, 4.871107956144127e-07)
# 4. dec_nolink_2x and dec_nolink_ux (3.3461380847145694, 0.0015985549346183938)
# 5. nondec_nolink_2x and nondec_nolink_ux (3.510689911797362, 0.0009833549535727508)
# 6. nondec_2x and nondec_nolink_2x 2.1395611776184236, 0.037502813864099094)

# 7. co_2x and nondec_2x (-14.127875309222032, 1.0085431333660833e-18)
# 8. co_ux and co_2x (-12.324237558169042, 1.7658518047299196e-16)

# %%
# number of fitness functions

# 1. co_2x and co_ux (4.501153039012651, 4.3044492144068645e-05)
# 2. nondec_2x and nondec_ux (4.273662673906907, 9.067927865351089e-05)
# 3. dec_nolink_2x and dec_nolink_ux (2.2594593249687525, 0.028432331072446977)
# 4. nondec_nolink_2xand nondec_nolink_ux (5.921930544951582, 3.298685553305906e-07)

# 5. dec_2x and nondec_2x (6.221245350631958, 1.1504448098118333e-07)
# 6. dec_ux and nondec_ux (5.3029833644668125, 2.8517634053326303e-06)
# 7. dec_nolink_2x and nondec_nolink_2x (5.1757744637930845, 4.4189958727765655e-06)
# 8. dec_nolink_ux and nondec_nolink_ux (3.9712621509162562, 0.00023873111040768593)

# 9. co_2x and nondec_2x (-8.369069113773355, 6.131982886119395e-11)

# %%
# average cpu time

# 1. co_2x and co_ux (-12.946810552653918, 2.834930764589794e-17)
# 2. dec_2x and dec_ux (-3.9994247775946885, 0.00021840956926954616)
# 3. nondec_2x and nondec_ux (-8.54430036870962, 3.355408963096147e-11)
# 4. nondec_nolink_2x and nondec_nolink_ux (-4.231726341544091, 0.00010387392344794893)

# 5. dec_2x and nondec_2x (5.5429999287313, 1.2410683155641384e-06)
# 6. dec_ux and nondec_ux (5.300845180690345, 2.87288716161481e-06)
# 7. dec_nolink_2x and nondec_nolink_2x (4.894792984963526, 1.1524739903553975e-05)
# 8. dec_nolink_ux and nondec_nolink_ux (3.7059802450478787, 0.0005446796939185359)

# 9. dec_2x and dec_nolink_2x (-3.242779465405812, 0.0021562195004261155)
#10. nondec_2x and nondec_nolink_2x (-9.550222901176461, e-17760495686898e-12)
#11. nondec_ux and nondec_nolink_ux (-3.170028058821423, 0.0026541372948095153)
